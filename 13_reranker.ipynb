# %%
from langchain_classic.retrievers.ensemble import EnsembleRetriever
from langchain_community.retrievers import BM25Retriever
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_community.document_compressors.flashrank_rerank import FlashrankRerank

# %%
# %pip install flashrank
# Out:
# Requirement already satisfied: flashrank in .\.venv\Lib\site-packages (0.2.10)
# Requirement already satisfied: tokenizers in .\.venv\Lib\site-packages (from flashrank) (0.22.2)
# Requirement already satisfied: onnxruntime in .\.venv\Lib\site-packages (from flashrank) (1.27.0)
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (from flashrank) (2.4.6)
# Requirement already satisfied: requests in .\.venv\Lib\site-packages (from flashrank) (2.34.2)
# Requirement already satisfied: tqdm in .\.venv\Lib\site-packages (from flashrank) (4.68.3)
# Requirement already satisfied: flatbuffers in .\.venv\Lib\site-packages (from onnxruntime->flashrank) (25.12.19)
# Requirement already satisfied: packaging in .\.venv\Lib\site-packages (from onnxruntime->flashrank) (25.0)
# Requirement already satisfied: protobuf>=4.25.8 in .\.venv\Lib\site-packages (from onnxruntime->flashrank) (6.33.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests->flashrank) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests->flashrank) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests->flashrank) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\Lib\site-packages (from requests->flashrank) (2026.6.17)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in .\.venv\Lib\site-packages (from tokenizers->flashrank) (1.21.0)
# Requirement already satisfied: click>=8.4.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (6.0.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (4.15.0)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (4.14.1)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in .\.venv\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.0.4)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.16.4->tokenizers->flashrank) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# SETUP: Create expanded sample company data (50+ chunks)

# %%
chunks = [
    # Tesla - Financial & Production
    "Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.",
    "Tesla's automotive gross margin improved to 19.3% this quarter.",
    "Tesla Cybertruck production ramp begins in 2024 with initial deliveries.",
    "Tesla announced plans to expand Gigafactory production capacity.",
    "Tesla stock price reached new highs following earnings announcement.",
    "Tesla's energy storage business grew 40% year-over-year.",
    "Tesla continues to lead in electric vehicle market share globally.",
    "Tesla Model Y became the best-selling vehicle worldwide.",
    "Tesla reported strong free cash flow generation of $7.5 billion.",
    "Tesla's Full Self-Driving revenue increased significantly.",
    
    # Microsoft - Development & Acquisitions
    "Microsoft acquired GitHub for $7.5 billion in 2018.",
    "Microsoft's cloud revenue Azure grew 29% year-over-year.",
    "Microsoft announced new AI features for Visual Studio Code.",
    "Microsoft Teams integration with GitHub enhances developer workflow.",
    "Microsoft's developer tools division sees strong adoption.",
    "Microsoft acquired Activision Blizzard for $68.7 billion.",
    "Microsoft's productivity suite gained 50 million new users.",
    "Microsoft announced new Surface devices for developers.",
    "Microsoft's AI Copilot features expand to more development tools.",
    "Microsoft's enterprise solutions drive revenue growth.",
    
    # NVIDIA - AI & Hardware
    "NVIDIA's data center revenue reached $47.5 billion annually.",
    "NVIDIA's H100 GPUs see unprecedented demand for AI training.",
    "NVIDIA announced next-generation Blackwell architecture.",
    "NVIDIA's gaming revenue declined due to crypto market changes.",
    "NVIDIA's automotive AI platform partnerships expanded.",
    "NVIDIA's AI chip shortage affects cloud providers.",
    "NVIDIA stock valuation exceeds $2 trillion market cap.",
    "NVIDIA's CUDA platform dominates AI development.",
    "NVIDIA announced new AI inference chips for edge computing.",
    "NVIDIA's partnership with major cloud providers strengthens.",
    
    # Google/Alphabet - AI & Cloud
    "Google's AI investments total over $100 billion in recent years.",
    "Google Cloud revenue grew 35% reaching $8.4 billion quarterly.",
    "Google announced Gemini AI model competing with GPT-4.",
    "Google's search advertising revenue remains strong at $59 billion.",
    "Google's Workspace products integrate advanced AI features.",
    "Google announced quantum computing breakthroughs.",
    "Google's autonomous vehicle division Waymo expands operations.",
    "Google's AI research published breakthrough papers.",
    "Google's cloud AI services see enterprise adoption.",
    "Google faces regulatory scrutiny over AI dominance.",
    
    # Noisy/Less Relevant Chunks
    "The Tesla coil was invented by Nikola Tesla in 1891.",
    "Microsoft Excel spreadsheet formulas can be complex for beginners.",
    "NVIDIA Shield TV streaming device gets software update.",
    "Google Maps navigation improved with real-time traffic data.",
    "Production delays affected multiple manufacturing sectors.",
    "Financial markets showed volatility during earnings season.",
    "Revenue recognition standards changed for software companies.",
    "Hardware components face supply chain constraints globally.",
    "Development tools market grows with remote work trends.",
    "AI research requires significant computational resources.",
    "Quarterly reports show mixed results across tech sector.",
    "Stock market analysts upgrade technology sector ratings.",
    "Cloud computing adoption accelerates in enterprise market.",
    "Data center construction increases globally.",
    "Semiconductor shortage impacts various industries.",
    "Electric vehicle charging infrastructure expands rapidly.",
    "Software development productivity tools gain popularity.",
    "Machine learning frameworks become more accessible.",
    "Enterprise software licensing models evolve.",
    "Technology conferences showcase latest innovations."
]

print(f"Created {len(chunks)} sample chunks for demonstration")
# Out:
# Created 60 sample chunks for demonstration

# %%
# Convert to Document objects
documents = [Document(page_content=chunk, metadata={"source": f"chunk_{i}"}) for i, chunk in enumerate(chunks)]

# %% [markdown]
#
# SETUP: Create the three types of retrievers
#
# # 1. Vector Retriever (Semantic Search/Dense Retrieval)

# %% [markdown]
# Setting up hybrid retriever...

# %%
embedding_model = OllamaEmbeddings(model="nomic-embed-text")
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embedding_model,
    collection_metadata={"hnsw:space": "cosine"}
)
vector_retriever = vectorstore.as_retriever(search_kwargs={"k": 15})

# %% [markdown]
# # 2. BM25 Retriever (Keyword Search/Sparse Retrieval)

# %%
# 2. BM25 Retriever
bm25_retriever = BM25Retriever.from_documents(documents)
bm25_retriever.k = 15

# %% [markdown]
# # 3. Hybrid Retriever

# %%
hybrid_retriever = EnsembleRetriever(
    retrievers=[vector_retriever, bm25_retriever],
    weights=[0.7, 0.3]
)

print("Setup complete!\n")
# Out:
# Setup complete!

# %% [markdown]
# Step 1: Get results from hybrid search (retrieve more chunks)

# %%
query = "Tesla financial performance and production updates"

print("STEP 1: Hybrid Search Results")
print("-"*50)

retrieved_docs = hybrid_retriever.invoke(query)  # Get top 25 for reranking

# Show top 10 from hybrid search
for i, doc in enumerate(retrieved_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print(f"\n(Retrieved {len(retrieved_docs)} total chunks for reranking)\n")
# Out:
# STEP 1: Hybrid Search Results
# --------------------------------------------------
#  1. Tesla announced plans to expand Gigafactory production capacity.
#  2. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#  3. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#  4. Tesla stock price reached new highs following earnings announcement.
#  5. Financial markets showed volatility during earnings season.
#  6. NVIDIA Shield TV streaming device gets software update.
#  7. Microsoft announced new AI features for Visual Studio Code.
#  8. Tesla's Full Self-Driving revenue increased significantly.
#  9. Microsoft's enterprise solutions drive revenue growth.
# 10. Tesla's automotive gross margin improved to 19.3% this quarter.
# 11. Production delays affected multiple manufacturing sectors.
# 12. Tesla's energy storage business grew 40% year-over-year.
# 13. Microsoft's cloud revenue Azure grew 29% year-over-year.
# 14. Google Cloud revenue grew 35% reaching $8.4 billion quarterly.
# 15. Google's autonomous vehicle division Waymo expands operations.
# 16. The Tesla coil was invented by Nikola Tesla in 1891.
# 17. Tesla Model Y became the best-selling vehicle worldwide.
# 18. Tesla continues to lead in electric vehicle market share globally.
# 19. Tesla reported strong free cash flow generation of $7.5 billion.
# 20. Electric vehicle charging infrastructure expands rapidly.
# 21. Technology conferences showcase latest innovations.
# 22. Machine learning frameworks become more accessible.
# 23. Enterprise software licensing models evolve.
# 24. Development tools market grows with remote work trends.
# 25. Hardware components face supply chain constraints globally.
#
# (Retrieved 25 total chunks for reranking)

# %% [markdown]
# Step 2: Apply Local FlashRank Reranking

# %%
print("STEP 2: After Local FlashRank Reranking (Top 10)")
print("-"*50)

# Initialize local FlashRank reranker
reranker = FlashrankRerank(top_n=10)

# Rerank the retrieved documents
reranked_docs = reranker.compress_documents(retrieved_docs, query)

# Show reranked results
for i, doc in enumerate(reranked_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print("\n" + "="*80)
print("ANALYSIS:")
print("✅ Hybrid Search: Mixed relevant and irrelevant results")
print("✅ Reranking: Most relevant Tesla financial/production info at top")
print("✅ Notice how reranking moved the most contextually relevant chunks higher")

# Optional: Show the difference more clearly
print("\n" + "="*80)
print("KEY IMPROVEMENTS AFTER RERANKING:")
print("-"*40)


hybrid_top_5 = [doc.page_content for doc in retrieved_docs[:5]]
reranked_top_5= [doc.page_content for doc in reranked_docs[:5]]

print("BEFORE (Hybrid Top 3):")
for i, content in enumerate(hybrid_top_5, 1):
    print(f"  {i}. {content}")

print("\nAFTER (Reranked Top 3):")
for i, content in enumerate(reranked_top_5, 1):
    print(f"  {i}. {content}")
# Out:
# STEP 2: After Local FlashRank Reranking (Top 10)
# --------------------------------------------------
#  1. Tesla announced plans to expand Gigafactory production capacity.
#  2. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#  3. Production delays affected multiple manufacturing sectors.
#  4. Tesla's energy storage business grew 40% year-over-year.
#  5. Tesla continues to lead in electric vehicle market share globally.
#  6. Tesla's Full Self-Driving revenue increased significantly.
#  7. Financial markets showed volatility during earnings season.
#  8. Technology conferences showcase latest innovations.
#  9. Tesla reported strong free cash flow generation of $7.5 billion.
# 10. Tesla Model Y became the best-selling vehicle worldwide.
#
# ================================================================================
# ANALYSIS:
# ✅ Hybrid Search: Mixed relevant and irrelevant results
# ✅ Reranking: Most relevant Tesla financial/production info at top
# ✅ Notice how reranking moved the most contextually relevant chunks higher
#
# ================================================================================
# KEY IMPROVEMENTS AFTER RERANKING:
# ----------------------------------------
# BEFORE (Hybrid Top 3):
#   1. Tesla announced plans to expand Gigafactory production capacity.
#   2. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#   3. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#   4. Tesla stock price reached new highs following earnings announcement.
#   5. Financial markets showed volatility during earnings season.
#
# AFTER (Reranked Top 3):
#   1. Tesla announced plans to expand Gigafactory production capacity.
#   2. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#   3. Production delays affected multiple manufacturing sectors.
#   4. Tesla's energy storage business grew 40% year-over-year.
#   5. Tesla continues to lead in electric vehicle market share globally.

# %% [markdown]
# FINAL RAG: Generate answer with reranked context

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_ollama import ChatOllama

print("\n" + "="*80)
print("FINAL: RAG with Reranked Context")
print("-"*40)

# Use top 5 reranked documents for final answer
top_reranked = reranked_docs[:5]

combined_input = f"""Based on the following documents, please answer this question: {query}

Documents:
{chr(10).join([f"- {doc.page_content}" for doc in top_reranked])}

Please provide a clear, helpful answer using only the information from these documents."""

model = ChatOllama(model="llama3.2:3b", temperature=0)
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content=combined_input),
]

result = model.invoke(messages)
print("Generated Response:")
print(result.content)
# Out:
# ================================================================================
# FINAL: RAG with Reranked Context
# ----------------------------------------
# INFO:httpx:HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Generated Response:
# Based on the provided documents, here are some key updates on Tesla's financial performance and production:
#
# 1. **Gigafactory expansion**: Tesla plans to expand its Gigafactory production capacity.
# 2. **Cybertruck production ramp**: The Cybertruck production is expected to begin in 2024 with initial deliveries scheduled for that year.
# 3. **Production delays**: There were production delays affecting multiple manufacturing sectors, but no specific details are provided on the impact of these delays.
# 4. **Energy storage business growth**: Tesla's energy storage business experienced a 40% year-over-year growth.
# 5. **Electric vehicle market share leadership**: Tesla continues to lead in electric vehicle market share globally.
#
# Overall, while there were production delays, Tesla is still expanding its capacity and ramping up new product lines, such as the Cybertruck, with initial deliveries expected in 2024.
